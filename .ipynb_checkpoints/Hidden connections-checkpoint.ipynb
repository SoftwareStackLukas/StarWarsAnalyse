# %% [markdown]
# # Pathfinder for Hidden connections
#
# #https://neo4j.com/docs/cypher-manual/current/introduction/uniqueness/
# #https://stackoverflow.com/questions/14345555/return-unique-nodes-in-cypher-path-query
# #https://github.com/neo4j/neo4j/issues/12628
# #How to improve it to just get once Episode I: The Phantom Menace?

# %%
#Imports
from neo4j import GraphDatabase, basic_auth
import neo4jupyter
import pandas as pd
from vis_class import vis_class

# %%
#Create db connector
login = open("Login.txt", "r")
uri = login.readline().strip()
user = login.readline().strip()
password = login.readline().strip()
login.close()
#uri = "bolt://localhost:7687"
#user = "neo4j"
#password = "neo4j"

driver = GraphDatabase.driver(uri, auth=basic_auth(user, password))
session = driver.session(database="neo4j")
vis_class()

# %% [markdown]
# ## General Path finding / matching

# %% [markdown]
# Here we get an short overview how characters are connected over max. 5 diffrent relations

# %%
five_path = '''MATCH p = ()-[*5]-() RETURN nodes(p) Limit 5'''
results = session.read_transaction(
    lambda tx: tx.run(five_path).data())
results
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18776/714855413.py in <module>
#       1 five_path = '''MATCH p = ()-[*5]-() RETURN nodes(p) Limit 5'''
# ----> 2 results = session.read_transaction(
#       3     lambda tx: tx.run(five_path).data())
#       4 results
#
# ~\anaconda3\lib\site-packages\neo4j\work\simple.py in read_transaction(self, transaction_function, *args, **kwargs)
#     394         :return: a result as returned by the given unit of work
#     395         """
# --> 396         return self._run_transaction(READ_ACCESS, transaction_function, *args, **kwargs)
#     397
#     398     def write_transaction(self, transaction_function, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\neo4j\work\simple.py in _run_transaction(self, access_mode, transaction_function, *args, **kwargs)
#     320         while True:
#     321             try:
# --> 322                 self._open_transaction(access_mode=access_mode, metadata=metadata, timeout=timeout)
#     323                 tx = self._transaction
#     324                 try:
#
# ~\anaconda3\lib\site-packages\neo4j\work\simple.py in _open_transaction(self, access_mode, metadata, timeout)
#     253     def _open_transaction(self, *, access_mode, metadata=None,
#     254                           timeout=None):
# --> 255         self._connect(access_mode=access_mode)
#     256         self._transaction = Transaction(
#     257             self._connection, self._config.fetch_size,
#
# ~\anaconda3\lib\site-packages\neo4j\work\simple.py in _connect(self, access_mode)
#     106         if access_mode is None:
#     107             access_mode = self._config.default_access_mode
# --> 108         super()._connect(access_mode)
#     109
#     110     def _collect_bookmark(self, bookmark):
#
# ~\anaconda3\lib\site-packages\neo4j\work\__init__.py in _connect(self, access_mode)
#      77                     database_callback=self._set_cached_database
#      78                 )
# ---> 79         self._connection = self._pool.acquire(
#      80             access_mode=access_mode,
#      81             timeout=self._config.connection_acquisition_timeout,
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in acquire(self, access_mode, timeout, database, bookmarks)
#    1184             log.debug("[#0000]  C: <ROUTING TABLE ENSURE FRESH> %r",
#    1185                       self.routing_tables)
# -> 1186             self.ensure_routing_table_is_fresh(
#    1187                 access_mode=access_mode, database=database, imp_user=None,
#    1188                 bookmarks=bookmarks
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in ensure_routing_table_is_fresh(self, access_mode, database, imp_user, bookmarks, database_callback)
#    1130                 return False
#    1131
# -> 1132             self.update_routing_table(
#    1133                 database=database, imp_user=imp_user, bookmarks=bookmarks,
#    1134                 database_callback=database_callback
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in update_routing_table(self, database, imp_user, bookmarks, database_callback)
#    1076             if prefer_initial_routing_address:
#    1077                 # TODO: Test this state
# -> 1078                 if self._update_routing_table_from(
#    1079                         self.first_initial_routing_address, database=database,
#    1080                         imp_user=imp_user, bookmarks=bookmarks,
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in _update_routing_table_from(self, database, imp_user, bookmarks, database_callback, *routers)
#    1028         for router in routers:
#    1029             for address in router.resolve(resolver=self.pool_config.resolver):
# -> 1030                 new_routing_table = self.fetch_routing_table(
#    1031                     address=address,
#    1032                     timeout=self.pool_config.connection_timeout,
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in fetch_routing_table(self, address, timeout, database, imp_user, bookmarks)
#     975         new_routing_info = None
#     976         try:
# --> 977             new_routing_info = self.fetch_routing_info(
#     978                 address, database, imp_user, bookmarks, timeout
#     979             )
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in fetch_routing_info(self, address, database, imp_user, bookmarks, timeout)
#     946             routing, or if routing support is broken or outdated
#     947         """
# --> 948         cx = self._acquire(address, timeout)
#     949         try:
#     950             routing_table = cx.route(
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in _acquire(self, address, timeout)
#     694                                   time_remaining())
#     695                     try:
# --> 696                         connection = self.opener(address, timeout)
#     697                     except ServiceUnavailable:
#     698                         self.remove(address)
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in opener(addr, timeout)
#     867
#     868         def opener(addr, timeout):
# --> 869             return Bolt.open(addr, auth=auth, timeout=timeout,
#     870                              routing_context=routing_context, **pool_config)
#     871
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     357
#     358         try:
# --> 359             connection.hello()
#     360         except Exception:
#     361             connection.close()
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4.py in hello(self)
#     441                                            on_success=on_success))
#     442         self.send_all()
# --> 443         self.fetch_all()
#     444         check_supported_server_product(self.server_info.agent)
#     445
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in fetch_all(self)
#     534             response = self.responses[0]
#     535             while not response.complete:
# --> 536                 detail_delta, summary_delta = self.fetch_message()
#     537                 detail_count += detail_delta
#     538                 summary_count += summary_delta
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4.py in fetch_message(self)
#     307             self._server_state_manager.state = ServerStates.FAILED
#     308             try:
# --> 309                 response.on_failure(summary_metadata or {})
#     310             except (ServiceUnavailable, DatabaseUnavailable):
#     311                 if self.pool:
#
# ~\anaconda3\lib\site-packages\neo4j\io\_common.py in on_failure(self, metadata)
#     260         code = metadata.get("code")
#     261         if code == "Neo.ClientError.Security.Unauthorized":
# --> 262             raise Neo4jError.hydrate(**metadata)
#     263         else:
#     264             raise ServiceUnavailable(
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}

# %% [markdown]
# ## Finding hidden path

# %% [markdown]
# Here we will find the connections (hidden path) between two nodes to see how the Star Wars Universe is connected

# %%
# Paths between unconnected Person - Movie (Max 4 relations per path)
person_movie = '''match searchPath=(ms:Movie)<-[*..4]->(ps:Person) 
                    WHERE ms.name="Episode II: Attack of the Clones" AND ps.name="KI-ADI-MUNDI" 
                    return DISTINCT searchPath'''

df = pd.DataFrame(session.read_transaction(
        lambda tx: tx.run(person_movie).data()))
df.head()
# Out:
# [{'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'VALORUM'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'VALORUM'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'VALORUM'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'SENATOR ASK AAK'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode III: Revenge of the Sith'},
#    'APPEARS_IN',
#    {'name': 'PLO KOON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'C-3PO'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'R2-D2'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'SOLA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'SOLA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'JOBAL'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'RUWEE'},
#    'SPEAKS_WITH',
#    {'name': 'JOBAL'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'ORN FREE TAA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'ORN FREE TAA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'SENATOR ASK AAK'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'TAUN WE'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'TAUN WE'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'LAMA SU'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
# ...
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'WATTO'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'WATTO'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'FODE/BEED'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JIRA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JIRA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JIRA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BOSS NASS'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BOSS NASS'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BOSS NASS'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BOSS NASS'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'GIDDEAN DANU'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'SOLA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'SOLA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'JAR JAR'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BERU'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BERU'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'CAPTAIN PANAKA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'CAPTAIN PANAKA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'CAPTAIN PANAKA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'CAPTAIN PANAKA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'CAPTAIN PANAKA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'MACE WINDU'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'BAIL ORGANA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'EMPEROR'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'QUI-GON'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'APPEARS_IN',
#    {'name': 'Episode I: The Phantom Menace'},
#    'APPEARS_IN',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'YODA'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  {'searchPath': [{'name': 'Episode II: Attack of the Clones'},
#    'APPEARS_IN',
#    {'name': 'PADME'},
#    'SPEAKS_WITH',
#    {'name': 'ANAKIN'},
#    'SPEAKS_WITH',
#    {'name': 'RABE'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]},
#  ...]

# %%
# Shortest path between unconnected Person - Movie (Max 4 relations per path)
# subquery to find the shortest and then query to get the one with the shortest length
person_movie = '''
    CALL {
        match p=(ms:Movie)<-[*..4]->(ps:Person)
        WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI"
        return min(length(p)) AS shortest
    }
    MATCH searchPath=(ms:Movie)<-[*..4]->(ps:Person)
    WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI" AND length(searchPath) = shortest
    return searchPath
'''
results = session.read_transaction(
    lambda tx: tx.run(person_movie).data())
results
# Out:
# [{'searchPath': [{'name': 'Episode IV: A New Hope'},
#    'APPEARS_IN',
#    {'name': 'OBI-WAN'},
#    'SPEAKS_WITH',
#    {'name': 'KI-ADI-MUNDI'}]}]

# %%
#Find path between Person and Person which are not related at the first glance
person_person = '''match searchPath=(ms:Movie)<-[*..4]->(ps:Person) 
                    WHERE ms.name="Episode II: Attack of the Clones" AND ps.name="KI-ADI-MUNDI" 
                    return DISTINCT searchPath'''

df = pd.DataFrame(session.read_transaction(
        lambda tx: tx.run(person_person).data()))
df.head()

# %%
person_person = '''
    CALL {
        match p=(ms:Movie)<-[*..4]->(ps:Person)
        WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI"
        return min(length(p)) AS shortest
    }
    MATCH searchPath=(ms:Movie)<-[*..4]->(ps:Person)
    WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI" AND length(searchPath) = shortest
    return searchPath
'''
df = pd.DataFrame(session.read_transaction(
    lambda tx: tx.run(person_person).data()))
df.head()

# %%
#Find path between Movie and Movie which are not related at the first glance
movie_movie = '''match searchPath=(ms:Movie)<-[*..4]->(ps:Person) 
                    WHERE ms.name="Episode II: Attack of the Clones" AND ps.name="KI-ADI-MUNDI" 
                    return DISTINCT searchPath'''

df = pd.DataFrame(session.read_transaction(
        lambda tx: tx.run(movie_movie).data()))
df.head()

# %%
movie_movie = '''
    CALL {
        match p=(ms:Movie)<-[*..4]->(ps:Person)
        WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI"
        return min(length(p)) AS shortest
    }
    MATCH searchPath=(ms:Movie)<-[*..4]->(ps:Person)
    WHERE ms.name="Episode IV: A New Hope" AND ps.name="KI-ADI-MUNDI" AND length(searchPath) = shortest
    return searchPath
'''
df = pd.DataFrame(session.read_transaction(
    lambda tx: tx.run(movie_movie).data()))
df.head()

# %% [markdown]
# ## Closing the connection to the database

# %%
#Close all connections
driver.close()
session.close()
drive = None
session = None
