# %% [markdown]
# # Counting
# In this notebook we will study some important features about Star Wars movies based on counting the number of nodes and relationships between them. We will analyse:
# - Which characters have the most appearences in all the movies
# - Which movie has the most characters / edges
# - Which node has the most edges

# %%
# Imports
from neo4j import GraphDatabase, basic_auth
import pandas as pd
from vis_class import vis_class

# %%
# DB connection
#uri = "bolt://localhost:7687"
#user = "neo4j"
#password = "neo4j"

login = open("Login.txt", "r")
uri = login.readline().strip()
user = login.readline().strip()
password = login.readline().strip()
login.close()

driver = GraphDatabase.driver(uri, auth=basic_auth(user, password))
session = driver.session(database="neo4j")

visualizer = vis_class()
# Out:
# Vis class was created

# %% [markdown]
# ## Which characters have the most appearences in all the movies

# %%
most_appear = '''
    MATCH p=(n)-[:APPEARS_IN]->()
    WHERE n:Person OR n:Droid
    RETURN n.name AS Name, count(RELATIONSHIPS(p)) AS Appearances
    ORDER BY Appearances DESC, Name
'''
results = session.read_transaction(
        lambda tx: tx.run(most_appear).data())
df = pd.DataFrame(results)
df
# Out:
#             Name  Appearances
# 0          C-3PO            7
# 1          R2-D2            7
# 2        OBI-WAN            6
# 3        EMPEROR            5
# 4           YODA            5
# ..           ...          ...
# 107  UNKAR PLUTT            1
# 108      VALORUM            1
# 109         WALD            1
# 110    YOLO ZIFF            1
# 111          ZEV            1
#
# [112 rows x 2 columns]

# %% [markdown]
# As we can see, C-3PO and R2-D2 are the only characters that appear in every movie.

# %%
most_appear = '''
    MATCH p=(ch)-[r:APPEARS_IN]->(m)
    WHERE ch.name='C-3PO'
    RETURN ch AS source_node, 
            id(ch) AS source_id,
            r,
            m AS target_node,
            id(m) As target_id
'''
#vis_class.power_drawGraph(driver, most_appear, node_size=1000, width=15, height=7, font_size=9)

# %%
vis_class.drawGraph(session, {'Movie':'name', 'Person':'name', 'Droid':'name'}, most_appear)
# Out:
# <div id="7c8457ab-2ff4-4a56-b9b7-5b1810b0f111" style="height: 400px;"></div>
#
# <script type="text/javascript">
#
#     var nodes = [{"id": 31, "label": "C-3PO", "group": "Droid", "title": "<Node id=31 labels=frozenset({'Droid'}) properties={'name': 'C-3PO'}>"}, {"id": 4, "label": "Episode V: The Empire Strikes Back", "group": "Movie", "title": "<Node id=4 labels=frozenset({'Movie'}) properties={'name': 'Episode V: The Empire Strikes Back'}>"}, {"id": 1, "label": "Episode II: Attack of the Clones", "group": "Movie", "title": "<Node id=1 labels=frozenset({'Movie'}) properties={'name': 'Episode II: Attack of the Clones'}>"}, {"id": 3, "label": "Episode IV: A New Hope", "group": "Movie", "title": "<Node id=3 labels=frozenset({'Movie'}) properties={'name': 'Episode IV: A New Hope'}>"}, {"id": 5, "label": "Episode VI: Return of the Jedi", "group": "Movie", "title": "<Node id=5 labels=frozenset({'Movie'}) properties={'name': 'Episode VI: Return of the Jedi'}>"}, {"id": 0, "label": "Episode I: The Phantom Menace", "group": "Movie", "title": "<Node id=0 labels=frozenset({'Movie'}) properties={'name': 'Episode I: The Phantom Menace'}>"}, {"id": 6, "label": "Episode VII: The Force Awakens", "group": "Movie", "title": "<Node id=6 labels=frozenset({'Movie'}) properties={'name': 'Episode VII: The Force Awakens'}>"}, {"id": 2, "label": "Episode III: Revenge of the Sith", "group": "Movie", "title": "<Node id=2 labels=frozenset({'Movie'}) properties={'name': 'Episode III: Revenge of the Sith'}>"}];
#     var edges = [{"from": 31, "to": 4, "label": "APPEARS_IN"}, {"from": 31, "to": 1, "label": "APPEARS_IN"}, {"from": 31, "to": 3, "label": "APPEARS_IN"}, {"from": 31, "to": 5, "label": "APPEARS_IN"}, {"from": 31, "to": 0, "label": "APPEARS_IN"}, {"from": 31, "to": 6, "label": "APPEARS_IN"}, {"from": 31, "to": 2, "label": "APPEARS_IN"}];
#
#     var container = document.getElementById("7c8457ab-2ff4-4a56-b9b7-5b1810b0f111");
#
#     var data = {
#         nodes: nodes,
#         edges: edges
#     };
#
#     var options = {
#     nodes: {
#         shape: 'dot',
#         size: 25,
#         font: {
#             size: 14
#         }
#     },
#     edges: {
#         font: {
#             size: 14,
#             align: 'middle'
#         },
#         color: 'gray',
#         arrows: {
#             to: {
#                 enabled: true,
#                 scaleFactor: 0.5
#             }
#         },
#         smooth: {
#             enabled: false
#         }
#     },
#     physics: {
#         enabled: true
#         }
#     };
#
#     var network = new vis.Network(container, data, options);
#
# </script>

# %% [markdown]
# ## Which movie has the most characters/edges

# %%
most_char = '''
    MATCH p=()--(m:Movie)
    RETURN m.name AS Title, count(p) AS NumberOfCharacters
    ORDER BY NumberOfCharacters DESC, Title
'''
results = session.read_transaction(
        lambda tx: tx.run(most_char).data())
df = pd.DataFrame(results)
df
# Out:
#                                 Title  NumberOfCharacters
# 0       Episode I: The Phantom Menace                  38
# 1    Episode II: Attack of the Clones                  33
# 2      Episode VII: The Force Awakens                  27
# 3    Episode III: Revenge of the Sith                  25
# 4              Episode IV: A New Hope                  22
# 5  Episode V: The Empire Strikes Back                  21
# 6      Episode VI: Return of the Jedi                  20

# %% [markdown]
# The movie with most edges is 'Episode I: The Phantom Menace'.

# %%
most_char = '''
    MATCH p=()--(m:Movie)
    WHERE m.name='Episode I: The Phantom Menace'
    RETURN p
'''
vis_class.power_drawGraph(driver, most_char, width=17, height=10)

# %% [markdown]
# ## Which node has the most edges

# %%
most_edges = '''
    MATCH p=(n)--()
    RETURN n.name AS Name, count(RELATIONSHIPS(p)) AS NumberOfEdges
    ORDER BY NumberOfEdges DESC, Name
'''
results = session.read_transaction(
        lambda tx: tx.run(most_edges).data())
df = pd.DataFrame(results)
df
# Out:
#                               Name  NumberOfEdges
# 0                           ANAKIN             46
# 1                            C-3PO             43
# 2                          OBI-WAN             43
# 3    Episode I: The Phantom Menace             38
# 4                            PADME             37
# ..                             ...            ...
# 114                         JANSON              2
# 115                      JERJERROD              2
# 116                        TARPALS              2
# 117                     TION MEDON              2
# 118                      GOLD FIVE              1
#
# [119 rows x 2 columns]

# %% [markdown]
# The node with most edges turns out to be the character named Anakin. We will see which of the nodes are characters and which are movies.

# %%
most_edges = '''
    MATCH p=(n)--()
    WHERE n.name='ANAKIN'
    RETURN p
'''
vis_class.power_drawGraph(driver, most_edges, width=17, height=10, node_size=1000, font_size=9)

# %% [markdown]
# As it's shown, this character has appeared in 4 of the movies and has spoken with 42 characters.

# %%
# Close all connections
driver.close()
session.close()
drive = None
session = None
